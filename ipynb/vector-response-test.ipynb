# %%
from gensim.models import KeyedVectors
from gensim.models.wrappers.fasttext import FastText
# Out:
# Using TensorFlow backend.

# %%
## load model
word2vec = KeyedVectors.load("../japanese-dataset/livedoor-news-corpus/model/vector-response-test/word2vec200.model")
word2vec_weighted = KeyedVectors.load("../japanese-dataset/livedoor-news-corpus/model/vector-response-test/word2vec_weighted.model")
fasttext = FastText.load_fasttext_format("../japanese-dataset/livedoor-news-corpus/model/vector-response-test/fasttext_model_200dim")
fasttext_weighted = KeyedVectors.load("../japanese-dataset/livedoor-news-corpus/model/vector-response-test/fasttext_weighted.model")
poincare_vec = KeyedVectors.load("../japanese-dataset/livedoor-news-corpus/model/vector-response-test/poincare_vec.model")
poincare_vec_weighted = KeyedVectors.load("../japanese-dataset/livedoor-news-corpus/model/vector-response-test/poincare_vec_weighted.model")

# %%
len(word2vec.most_similar("独身"))
# Out:
# 10

# %%
model_list = [word2vec,word2vec_weighted,fasttext,fasttext_weighted,poincare_vec,poincare_vec_weighted]
column_list = ["word2vec","word2vec_weighted","fasttext","fasttext_weighted","poincare_vec","poincare_vec_weighted"]

# %%
import pandas as pd
target_words = ["女性","男性","彼氏","ダイエット","ホテル","新しく",
                "エンジニア","アップル","転職","無料","もうすぐ",
                "終わり","コンビニ","確率",
                "アンドロイド","アプリ","本田圭佑","サッカー","コピー"]
result = pd.DataFrame(target_words)
result.columns = ["target_words"]

# %%
for name,model in zip(column_list,model_list):
    res = []
    for target in target_words:
        similars = model.most_similar(target)
        sim_res = []
        for sim in similars:
            sim_res.append(sim[0])
        res.append(" ".join(sim_res))
    result[name] = res
# Out:
# /Users/01018534/.pyenv/versions/3.6.1/lib/python3.6/site-packages/gensim/models/keyedvectors.py:826: RuntimeWarning: invalid value encountered in true_divide
#   self.syn0norm = (self.syn0 / sqrt((self.syn0 ** 2).sum(-1))[..., newaxis]).astype(REAL)

# %%
result
# Out:
#    target_words                                           word2vec  \
# 0            女性                         男性 女 男 人 女子 恋愛 独女 外見 代 女の子
# 1            男性                        女性 彼氏 男 異性 歳 既婚 女 Sさん 彼女 相手
# 2            彼氏                    付き合っ 彼女 彼 男性 結婚 私 別れ つきあっ 同棲 趣味
# 3         ダイエット            痩せ エクササイズ 痩せる やせ 運動 美容 脂肪 体重 デトックス カロリー
# 4           ホテル           レストラン 宿泊 リゾート 客室 ディナー ラグジュアリー 高層 階 施設 高級
# 5           新しく           予定 新モデル 追記 追加 開始 使い方 今夏 Android版 今回 夏モデル
# 6         エンジニア                 外資 新卒 転身 外資系 ベンチャー 入社 営業 高収入 人材 何人
# 7          アップル    サムスン 特許 iOS Apple ジョブズ iCloud WWDC iPad 米 Nexus
# 8            転職     求人 年収 type 求人情報 情報提供 薬剤師 仕事 情報コンテンツ 新卒 キャリアアップ
# 9            無料           価格 アプリ 料金 カテゴリ 開発者 有料 ANDROID バージョン Co 料
# 10         もうすぐ     ゴールデンウィーク 春 帰省 EXILIM 休止 薄着 そろそろ 撮り 早く ふぉっくす紺子
# 11          終わり        いつか 終わる 本番 始まり 楽しい 出来事 近づき 終わっ 笑っていいとも まもなく
# 12         コンビニ      セブンイレブン 弁当 おにぎり レシピ スイーツ 食べ 食べる Perfect パスタ 鶏
#                                          poincare_vec  \
# 0                      人生 妊娠 服 読ん 当たり前 家族 育児 なに 生活 人事
# 1                   男 それでも おしゃれ 食事 に対して 言わ 先輩 まだ 食 同僚
# 2                    子供 理想 相手 言葉 女の子 娘 嬉しい 決断 らしい 大好き
# 3                 興味 気 気味 あなた なのか 気づか 要素 転勤 朝 モチベーション
# 4         山口智充 吹石一恵 薄い こだわり ホンダ 毛穴 キンドル 初心者 アクティブ 平岳大
# 5                    見栄え 術 タブ どろん 開く 完了 登録 おこ 印刷 スライド
# 6      総合 日本テレビ 館 生放送 症 GIGABYTE Copyright 開幕 計測 提供開始
# 7          有料 HDMI ドコモ V ISWHT フルHD net セット 超 Express
# 8       bizreach 不足 一般 あらゆる Scope ため Google 前半 求人 奥行き
# 9                 W A 世界初 B 千 販売価格 iPhoneS ELUGA 未定 名
# 10                   軽い 定番 アイ に関して レベル 弱 器具 甘く ドバイ モノ
# 11                      語る 目 苦言 レッスン 春 高い たち CN 世代 年生
# 12                    では 苦労 生きる 身近 意識 願い 嬉しく 薬 現場 友だち
# 13             方 ▲ サイクルモード 工夫 やり取り 撮ら 大学生 イライラ マナー ハリ
# 14               販売元 金 クチコミ 概要 月 デュアル 付 TV ナビ Edition
# 15     オフィシャルサイト 全 ハンゲーム Tab スタンド 出力 仕様 任天堂 共著 market
# 16         照射 家電量販店 GDDR 型番 in KDDI 保証 局 Twin スタイリッシュ
# 17                   バッグ 読ま と 高校生 両者 見方 常識 いわゆる 試合 立つ
# 18  Googleドライブ 発音 ファイル 一条真人 乗り換え 入力 Dropbox 付け アドオ...
#
#                                 poincare_vec_weighted
# 0                  今日 妊娠 なに サラリーマン 存在 派遣 両親 変化 勘違い 年下
# 1                       先輩 同僚 一番 相手 女子 彼氏 既婚 年齢 友人 夫婦
# 2                       子供 相手 夫婦 先輩 男性 女子 同僚 友人 既婚 一緒
# 3              気味 なのか 要素 走る モチベーション どうして 仲良く イイ 想い 離婚
# 4                 こだわり キンドル 作れ ただし 使い 含め くさっ 筆者 よい 高く
# 5             見栄え 開く おこ 印刷 パスワード 通知 ウェブページ ワン 範囲 そのまま
# 6       生放送 提供開始 nejp ニコン 太陽 カナダ 初回 フレッシュ 優待 スペシャルサイト
# 7                セット 含む net 国内 資料 未定 入り acro 発売予定 rpm
# 8   求人 livedoor http type jp 競合 ミッドレンジ ハードウェアスペック ...
# 9   連続 ブログメディア ブラック として docomo カテゴリ による おサイフケータイ モ...
# 10               軽い 定番 アイ レベル 器具 甘く ドバイ 反面 カッコイイ あっさり
# 11                地元 学生 影響 小学生 震災 教育 今や ビデオサロン にくい 空気
# 12              苦労 生きる 友だち 指輪 辛口 目標 カップル 見つける 刺激 好きな人
# 13              工夫 やり取り 撮ら 大学生 イライラ ハリ 凄く ホルモン やがて 輪行
# 14             概要 the ナビ スタンダード エプソン えむ 有料 ぴー 克彦 ドライブ
# 15            公式サイト ページ 特集 ビューアー レビュー 記事 見る 編集部 情報 デジ
# 16  家電量販店 スタイリッシュ した scene グラボ パナソニックモバイルコミュニケーション...
# 17                 読ま 両者 見方 常識 いわゆる 立つ 隠す どころか 家庭内 昨今
# 18            発音 一条真人 ホーム ブラウザ 行える 文字 オプション 録音 自動的 範囲
